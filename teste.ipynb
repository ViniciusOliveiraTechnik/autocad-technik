# %%
tags = ['\\pxqj;The information and/or design or configuration disclosed\\Pherein or in articles delivered is proprietary with TECHNIK, and shall not be duplicated, used or disclosed \\Pto reproduce articles or subject matter covered therein without\\Pwritten permission of TECHNIK.', 'DOCUMENTOS DE REFERÊNCIA', 'TAG', 'LISTA DE EQUIPAMENTOS', '-', '-', '-', '-', 'DES.', 'DATA', 'APROV.', 'VERIF.', 'DESCRIÇÃO', 'REV.', 'EGA', '15/08/24', 'MCM', 'FGG', 'FOR APPROVAL/COMMENTS', '0', '\\A1;\\pxql;N{\\H0.7x;\\So^;} DESENHO FORNECEDOR', '\\A1;\\pxql;N{\\H0.7x;\\So^;} DESENHO', '\\A1;\\pxql;TÍTULO', '\\A1;\\pxqc;AMPLIAÇÃO DA FÁBRICA DE LEVEDURAS', '\\A1;\\pxql;PROJETO', '\\A1;ALLTECH DO BRASIL - UNIDADE SÃO PEDRO DO IVAÍ - PR ', '\\A1;\\pxql;EMPRESA', '\\A1;\\pxql;REV', '\\A1;\\pxqc;1', '\\A1;\\pxql;FOLHA', '\\A1;\\pxqc;1/1', '\\A1;\\pxql;ESCALA', '\\A1;\\pxqc;NA', '\\A1;\\pxql;ÁREA', '\\A1;\\pxqc;BIOTECNOLOGIA', '\\A1;\\pxqc;DE-0695-PR-0009', '\\A1;\\pxqc;XXXXXX', '\\A1;\\pxqc;FERMENTADOR 1', 'DESCRIÇÃO', '-', '-', '-', '-', '-', '-', '-', '-', 'B-350701', 'TC-350701', 'F-350701', 'BOMBA DE DE PRODUTO', 'TROCADOR DE CALOR DE PRODUTO', 'FERMENTADOR 1', 'FERMENTADOR 1', '\\A1;\\pxqc;FIT\\P{\\W0.7;350710}', '\\A1;\\pxqc;TI\\P{\\W0.8;350737}', '\\A1;\\pxqc;PI\\P{\\W0.8;350738}', '\\A1;\\pxql;ÁGUA DE RESFRIAMENTO', '\\A1;\\pxql;0-TTE-0023\\P1000-AR-002-3-32"', '\\A1;DE-0695-PR-0010\\PSAÍDA DO F-350901(F2)', '\\A1;B-350701', '\\A1;\\pxqc;AIT\\P{\\W0.7;350724}', '\\A1;\\pxqc;PHIT\\P{\\W0.7;350723}', '\\A1;\\pxqc;S', '\\A1;F-350701', '\\A1;TC-350701', '\\A1;\\pxqc;5m', '\\A1;\\pxqc;O{\\H0.7x;\\S^2;}', '\\A1;\\pxqc;TIT\\P{\\W0.7;350727}', '\\A1;\\pxqc;{\\W0.8;TIC\\P350727}', '\\A1;\\pxqc;FIT\\P{\\W0.7;350708}', '\\A1;\\pxqc;TV\\P{\\W0.8;350727}', '\\A1;\\pxqc;FIT\\P{\\W0.7;350706}', '\\A1;\\pxqc;FV\\P{\\W0.8;350706}', '\\A1;\\pxqc;ZS\\P{\\W0.7;350721}', '\\A1;\\pxqc;{\\W0.8;ZSC\\P350721}', '\\A1;\\pxqc;LIT\\P{\\W0.7;350722}', '\\A1;\\pxqc;{\\W0.8;LI\\P350722}', '\\A1;\\pxqc;LS\n{\\W0.8;350719}', '\\A1;\\pxqc;{\\W0.8;LSL\\P350719}', '\\A1;\\pxqc;XV\\P{\\W0.8;350726}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725A}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725B}', '\\A1;\\pxqc;XV\\P{\\W0.8;350741}', '\\A1;\\pxqc;XV\\P{\\W0.8;350742}', '\\A1;\\pxqc;XV\\P{\\W0.8;350720}', '\\A1;\\pxqc;XV\\P{\\W0.8;350705}', '\\A1;\\pxqc;XV\\P{\\W0.8;350709}', '\\A1;\\pxqc;XV\\P{\\W0.8;350712}', '\\A1;\\pxqc;FV\\P{\\W0.8;350708}', '\\A1;\\pxqc;FV\\P{\\W0.8;350710}', '\\A1;\\pxqc;FIC\\P{\\W0.8;350706}', '\\A1;\\pxqc;FQIC\\P{\\W0.8;350708}', '\\A1;\\pxqc;FQIC\\P{\\W0.8;350710}', '\\A1;\\pxqc;TI\\P{\\W0.8;350733}', '\\A1;\\pxqc;PI\\P{\\W0.8;350734}', '\\A1;\\pxqc;TI\\P{\\W0.8;350735}', '\\A1;\\pxqc;PI\\P{\\W0.8;350736}', '\\A1;\\pxqc;TI\\P{\\W0.8;350739}', '\\A1;\\pxqc;PI\\P{\\W0.8;350740}', '\\A1;\\pxql;350-VSE-605-X-3"', '\\A1;\\pxql,t25;350-CIP-007-6-2-2.1/2"', '\\A1;\\pxql;350-IN-504-2-10"', '\\A1;\\pxql;450-PD-111-2-2"', '\\A1;100-SA-058-2-6"', '\\A1;\\pxql;350-AF-001-6-5-1"', '\\A1;\\pxql;450-UR-006-6-5-1.1/2"', '\\A1;1000-AE-002-2-28"', '\\A1;\\pxql;350-MO-705-2-10"', '\\A1;\\pxql;350-MO-706-2-10"', '\\A1;\\pxql;350-SA-704-2-6"', '\\A1;\\pxql;100-MO-406-2-3"', '\\A1;\\pxql;350-AE-701-X-16"', '\\A1;\\pxql;350-CIP-711-2-6"', '\\A1;\\pxql;350-AR-004-6-3-10"', '\\A1;\\pxql;350-AR-708-3-10"', '\\A1;\\pxql;350-MO-709-2-12"', '\\A1;\\pxql;350-MO-710-2-10"', '\\A1;\\pxql;350-UR-703-8-11/2"', '\\A1;\\pxql;350-AF-007-6-5-1/2"', '\\A1;\\pxql;350-MO-702-2-2"', '\\A1;\\pxqc;{\\C0;V=230 m\\fSansSerif|b0|i0|c2|p2;³}', 'FI-350701', 'FILTRO DE AR DE PROCESSO DO F1', 'NOTAS GERAIS', 'RANGE', 'LAST NO.', 'LINES', 'INSTRUMENTS', 'CANCELLED', 'RANGE', 'LAST NO.', 'CANCELLED', '\\A1;701-800', '\\A1;\\pxql;713', '\\A1;350701-350800', '\\A1;350742', '\\A1;FERMENTADO', '\\A1;\\pxql;ÁCIDO FOSFÓRICO', '\\A1;\\pxql;SAIS ', '\\A1;ADITIVOS', '\\A1;UREIA', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0010\nB-450101', '\\A1;\\pxql;CIP', '\\A1;\\pxql;AR DE PROCESSO', '\\A1;MOSTO ESTERILIZADO', '\\A1;INÓCULO', '\\A1;DE-0695-PR-0008\\PTC-350501', '\\A1;DE-0695-PR-0014\\P300-CIP-001-6-2-2.1/2"', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;\\pxql;ÁCIDO FOSFÓRICO', '\\A1;\\pxql;SAIS ', '\\A1;UREIA', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;\\pxql;AR DE PROCESSO', '\\A1;MOSTO', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0014\\P1000-CIP-003-6-2-4"', '\\A1;CIP', '\\A1;\\pxql;DE-0695-PR-0014\\P300-CIP-0027-6-2-6"', '\\A1;\\pxql;DE-0695-PR-0014\\P300-CIP-0027-6-2-6"', '\\A1;VAPOR', '\\A1;DE-0695-PR-0015\\PVAPOR ESTÉRIL', '\\A1;\\pxqc;TIE-IN\n021', '\\A1;\\pxqc;TIE-IN\n020', '\\A1;\\pxql;350-CIP-456-2-4"', '\\A1;\\pxqc;XV\\P{\\W0.8;350702}', '\\A1;\\pxqc;DETALHE 1', '\\A1;\\pxql;AMÔNIA', '\\A1;\\pxqc;FIT\\P{\\W0.7;XXX}', '\\A1;\\pxqc;FIC\\P{\\W0.8;XXX}', '\\A1;\\pxqc;S', '\\A1;\\pxql;TUBULAÇÃO\nEXISTENTE', '\\A1;\\pxql;DETALHE 1', '\\A1;\\pxqc;TIE-IN\n00X', '\\A1;\\pxql;350-CIP-707-2-6"', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P730A}', '\\A1;\\pxql;12"x6"', '\\A1;\\pxql;DETALHE 2', '\\A1;\\pxql;DETALHE 3', '\\A1;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725C}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n728A}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n728B}', '\\A1;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P730C}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n713A}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n714A}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n707B}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n713B}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n714B}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P715B}', '\\A1;ANTIESPUMANTE', '\\A1;DE-0695-PR-0010\\PF-350901(F2)', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;400-AES-002-10-6-1/2"', '\\A1;\\pxql;300-AES-008-10-6-1/2"', '\\A1;ANTIESPUMANTE', '\\A1;AMÔNIA', '\\A1;DE-0695-PR-0015\\P\\pxql;1000-AM-002-18-1-1"', '\\A1;\\pxt6;RETORNO ÁGUA DE RESF.', '\\A1;\\pxqr;0-TTE-0023\\P1000-AR-001-3-32"', '\\A1;\\pxql;350-AM-611-X-1/2"', '\\A1;\\pxql;ADITIVOS', '\\A1;DE-0695-PR-0008\\PP-350501(P2)', '\\A1;\\pxqc;XV\\P{\\W0.8;350716}', '\\A1;\\pxqc;FIT\\P{\\W0.7;350717}', '\\A1;\\pxqc;FV\\P{\\W0.8;350717}', '\\A1;\\pxqc;FQIC\\P{\\W0.8;350717}', '\\A1;\\pxql;350-PD-712-X-1/2"', '\\A1;\\pxqc;PIT\\P{\\W0.7;350718}', '\\A1;\\pxqc;1m', '\\A1;SST', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P715D}', '\\A1;\\pxqc;TIE-IN\n024', '\\A1;\\pxqc;TIE-IN\n025', 'ST', '\\A1;\\pxqc;XV\\P{\\W0.8;350731}', '\\A1;\\pxqc;XV\\P{\\W0.8;350732}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P730B}', '\\A1;6"', '\\A1;6"', '\\A1;1"', '\\A1;\\pxql;1%', '\\A1;\\pxqc;XV\\P{\\W0.8;350729}', '\\A1;\\pxqc;FI-350701', '\\A1;\\pxql;350-AE-006-6-2-16"', '{\\Fromans|c0;EXISTENTE}', 'LEGENDA', '{\\Fromans|c0;NOVO}', '\\A1;\\pxqc;TIE-IN\n028', '\\A1;\\pxt16;DE-0695-PR-0010\\P\\ptz;F-350901(F2)', '\\A1;\\pxqc;XV\\P{\\W0.8;350704}', '\\A1;LPS', '\\A1;\\pxqc;PIT\\P{\\W0.8;350703}', '\\A1;\\pxqc;PI\n{\\W0.8;350703}', '\\A1;\\pxqc;PI\\P{\\W0.8;350701}', '\\pxql;min', '\\pxql;min', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P728D}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P728C}', '\\pxql;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725D}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725F}', '\\pxql;min', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P725E}', '\\pxql;LPS', '\\A1;\\pxqc;PV\\P{\\W0.8;350718}', '\\A1;\\pxqc;{\\W0.8;PIC\\P350718}', '\\A1;X"xX"', '\\A1;\\pxqc;PSV\\P{\\W0.8;350711}', '\\A1;LPS', '\\pxql;min', '\\pxql;min', '\\pxql;min', '\\pxql;min', '\\pxql;min', '\\pxql;min', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P721}', '\\pxql;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P713C}', '\\pxql;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P713D}', '\\pxql;ST', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P714D}', '\\pxql;SST', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P715A}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P715C}', '\\A1;SST', '\\A1;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\nXXXE}', '\\A1;LPS', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n00XD}', '\\A1;\\pxqc;XV\\P{\\W0.8;350\n00XC}', '\\A1;\\pxqc;GLOBO \\PANGULAR', 'EGA', '13/09/24', 'MCM', 'FGG', 'AS PER COMMENTS  ', '1', '\\pxql;min', '\\A1;\\pxql;1%', '\\A1;\\pxql;1%', '\\A1;\\pxqc;XV\\P{\\W0.8;350\\P707A}', '\\A1;\\pxqc;DET. 2', '\\pxql;ST', '\\A1;\\pxqc;{\\fSansSerif|b0|i0|c2|p2;MAN WAY }', '\\A1;{\\fSansSerif|b0|i0|c2|p2;\\P\\pxqc;24"}', '\\A1;\\pxql;350-AE-713-X-16"', '\\A1;LPS', '\\A1;\\pxqc;DET. 2', '\\A1;\\pxt6;CIPR (B-300012)', '\\A1;\\pxt6;CIPR (B-300012)', '\\A1;\\pxqc;DET. 3', '\\A1;\\pxql;1%', '\\A1;\\pxqc;TIE-IN\n022', '\\A1;\\pxqc;TIE-IN\n023', '\\A1;\\pxqc;TIE-IN\n026', '\\A1;\\pxqc;TIE-IN\n027', '\\pxql;min', '\\A1;\\pxqc;TIE-IN\n029']

# %%
import pandas as pd
import re

# %%
df = pd.DataFrame(tags, columns=['old_tag'])

# %%
regex = df

# %%
regex
# Out:
#                                                old_tag
# 0    \pxqj;The information and/or design or configu...
# 1                             DOCUMENTOS DE REFERÊNCIA
# 2                                                  TAG
# 3                                LISTA DE EQUIPAMENTOS
# 4                                                    -
# ..                                                 ...
# 304                              \A1;\pxqc;TIE-IN\n023
# 305                              \A1;\pxqc;TIE-IN\n026
# 306                              \A1;\pxqc;TIE-IN\n027
# 307                                          \pxql;min
# 308                              \A1;\pxqc;TIE-IN\n029
#
# [309 rows x 1 columns]

# %%
regex['old_tag'] = regex['old_tag'].map(lambda x: re.sub(r'(?:[\\]{1,2}[a-zA-Z]+[\d]+[.][\d]+)|([\\]{1,2}px[\w]+)|([^\w\s\\n-])|([\\]{1,2}[^\\n\\P][\w]+)', '', str(x)))

# %%
regex.values
# Out:
# array([['The information andor design or configuration disclosed\\Pherein or in articles delivered is proprietary with TECHNIK and shall not be duplicated used or disclosed \\Pto reproduce articles or subject matter covered therein without\\Pwritten permission of TECHNIK'],
#        ['DOCUMENTOS DE REFERÊNCIA'],
#        ['TAG'],
#        ['LISTA DE EQUIPAMENTOS'],
#        ['-'],
#        ['-'],
#        ['-'],
#        ['-'],
#        ['DES'],
#        ['DATA'],
#        ['APROV'],
#        ['VERIF'],
#        ['DESCRIÇÃO'],
#        ['REV'],
#        ['EGA'],
#        ['150824'],
#        ['MCM'],
#        ['FGG'],
#        ['FOR APPROVALCOMMENTS'],
#        ['0'],
#        ['Nx DESENHO FORNECEDOR'],
#        ['Nx DESENHO'],
#        ['TÍTULO'],
#        ['AMPLIAÇÃO DA FÁBRICA DE LEVEDURAS'],
#        ['PROJETO'],
#        ['ALLTECH DO BRASIL - UNIDADE SÃO PEDRO DO IVAÍ - PR '],
#        ['EMPRESA'],
#        ['REV'],
#        ['1'],
#        ['FOLHA'],
#        ['11'],
# ...
